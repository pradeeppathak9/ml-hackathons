# %%
# %load_ext autoreload
# %autoreload 2

from __future__ import division
import pandas as pd
import numpy as np
import copy
import pickle
import sys
import gc
from lightgbm import LGBMClassifier
from custom_estimator import Estimator
from sklearn.externals import joblib
pd.options.display.max_columns=200
pd.options.display.max_rows=100
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def create_feats(df):
    df.degree_source=df.degree_source.astype('float32')
    df.degree_target=df.degree_target.astype('float32')
    
    df['degree_ratio']=df.degree_source/(1+df.degree_target)
    df['degree_delta']=df.degree_source-df.degree_target
    
    df['directed_degree_ratio']=df.directed_degree_source/(1+df.directed_degree_target)
    df['directed_degree_delta']=df.directed_degree_source-df.directed_degree_target

    df['directed_degree_ratio_in']=df.directed_degree_source_in/(1+df.directed_degree_target_in)
    df['directed_degree_delta_in']=df.directed_degree_source_in-df.directed_degree_target_in

    df['directed_degree_ratio_out']=df.directed_degree_source_out/(1+df.directed_degree_target_out)
    df['directed_degree_delta_out']=df.directed_degree_source_out-df.directed_degree_target_out

    df['node_sum']=df['node1_id']+df['node2_id']
    df['node_ratio']=(df['node1_id']/df['node2_id']).astype('float16')
    
    df['is_chat_diff']=df['source_is_chat_count']-df['target_is_chat_count']
    df['is_chat_ratio']=(df['source_is_chat_count']/(df['target_is_chat_count']+1).astype('float16'))
    
    df['mutual_chat_diff']=df['source_mutual_is_chat']-df['target_mutual_is_chat']
    df['mutual_chat_ratio']=(df['source_mutual_is_chat']/(df['target_mutual_is_chat']+1).astype('float16'))

    
    df['delta_triangle']=df['node1_triangles']- df['node2_triangles']
    df['ratio_triangle']=df['node1_triangles']/(1+df['node2_triangles'])
    df['triangle_degree_delta_source']=(df.degree_source*8264276).astype('int16')-df['node1_triangles']
    df['triangle_degree_delta_target']=(df.degree_target*8264276).astype('int16')-df['node1_triangles']

    df['clust_prod']=df['node1_cluster']* df['node2_cluster']
    df['clust_diff']=df['node1_cluster']- df['node2_cluster']

    gc.collect()
    
    df['source_net_act']=df[['f1_source_target', 'f2_source_target', 'f3_source_target', 'f4_source_target', 'f5_source_target',
     'f6_source_target', 'f7_source_target', 'f8_source_target', 'f9_source_target', 'f10_source_target',
     'f11_source_target', 'f12_source_target']].sum(axis=1)

    df['target_net_act']=df[['f1_target', 'f2_target', 'f3_target',
     'f4_target', 'f5_target', 'f6_target', 'f7_target', 'f8_target', 'f9_target', 'f10_target', 'f11_target',
     'f12_target']].sum(axis=1)

    df['net_act_diff']=df['source_net_act']- df['target_net_act']

    gc.collect()
    

    df['f14_source']=df['f1_source_target']+df['f4_source_target']+df['f7_source_target']+df['f10_source_target']
    df['f15_source']=df['f5_source_target']+df['f8_source_target']+df['f11_source_target']
    df['f16_source']=df['f6_source_target']+df['f9_source_target']+df['f12_source_target']


    df['f14_target']=df['f1_target']+df['f4_target']+df['f7_target']+df['f10_target']
    df['f15_target']=df['f5_target']+df['f8_target']+df['f11_target']
    df['f16_target']=df['f6_target']+df['f9_target']+df['f12_target']

    gc.collect()
    
    df['fdiff_1']=df['f1_source_target']-df['f1_target']
    df['fdiff_2']=df['f2_source_target']-df['f2_target']
    df['fdiff_3']=df['f3_source_target']-df['f3_target']
    df['fdiff_4']=df['f4_source_target']-df['f4_target']
    df['fdiff_5']=df['f5_source_target']-df['f5_target']
    df['fdiff_6']=df['f6_source_target']-df['f6_target']
    df['fdiff_7']=df['f7_source_target']-df['f7_target']
    df['fdiff_8']=df['f8_source_target']-df['f8_target']
    df['fdiff_9']=df['f9_source_target']-df['f9_target']
    df['fdiff_10']=df['f10_source_target']-df['f10_target']
    df['fdiff_11']=df['f11_source_target']-df['f11_target']
    df['fdiff_12']=df['f12_source_target']-df['f12_target']
    df['fdiff_13']=df['f13_source_target']-df['f13_target']
    df['fdiff_14']=df['f14_target']-df['f14_source']
    df['fdiff_15']=df['f15_target']-df['f15_source']
    df['fdiff_16']=df['f16_target']-df['f16_source']

    gc.collect()
    
    
    df['fmult_1']=df['f1_source_target']/(df['f1_target']+1).astype('float16')
    df['fmult_2']=df['f2_source_target']/(1+df['f2_target']).astype('float16')
    df['fmult_3']=df['f3_source_target']/(1+df['f3_target']).astype('float16')
    df['fmult_4']=df['f4_source_target']/(1+df['f4_target']).astype('float16')
    df['fmult_5']=df['f5_source_target']/(1+df['f5_target']).astype('float16')
    df['fmult_6']=df['f6_source_target']/(1+df['f6_target']).astype('float16')
    df['fmult_7']=df['f7_source_target']/(1+df['f7_target']).astype('float16')
    df['fmult_8']=df['f8_source_target']/(1+df['f8_target']).astype('float16')
    df['fmult_9']=df['f9_source_target']/(1+df['f9_target']).astype('float16')
    df['fmult_10']=df['f10_source_target']/(1+df['f10_target']).astype('float16')
    df['fmult_11']=df['f11_source_target']/(1+df['f11_target']).astype('float16')
    df['fmult_12']=df['f12_source_target']/(1+df['f12_target']).astype('float16')
    df['fmult_13']=df['f13_source_target']/(1+df['f13_target']).astype('float16')
    df['fmult_14']=df['f14_source']/(1+df['f14_target']).astype('float16')
    df['fmult_15']=df['f15_source']/(1+df['f15_target']).astype('float16')
    df['fmult_16']=df['f16_source']/(1+df['f16_target']).astype('float16')

    gc.collect()
    

    df['norm_user_diff']=np.sqrt(np.square(df[df.columns[df.columns.str.contains('diff')]].astype('int16')).sum(axis=1))
    
    df['norm_user_diff_1']=np.sqrt(np.square(train[['fdiff_1','fdiff_4','fdiff_7','fdiff_10']].astype('int16')).sum(axis=1))
    df['norm_user_diff_2']=np.sqrt(np.square(train[['fdiff_2','fdiff_5','fdiff_8','fdiff_11']].astype('int16')).sum(axis=1))
    df['norm_user_diff_3']=np.sqrt(np.square(train[['fdiff_3','fdiff_6','fdiff_9','fdiff_12']].astype('int16')).sum(axis=1))

    df['source_net_act']=df['source_net_act'].astype('int16')
    df['target_net_act']=df['target_net_act'].astype('int16')
    df['net_act_diff']=df['net_act_diff'].astype('int16')
    df['norm_user_diff']=df['norm_user_diff'].astype('float16')

    gc.collect()
    
    
    return df

# %%
# %%time
train=pd.read_pickle('freq_new_train.pkl')
clust=pd.read_pickle('cluster_coeffs.pkl')
triangles=pd.read_pickle('triangles.pkl')
train['node1_cluster']=clust.clust_source.iloc[:train.shape[0]].values
train['node2_cluster']=clust.clust_target.iloc[:train.shape[0]].values
train['node1_triangles']=triangles.triangles_source.iloc[:train.shape[0]].values
train['node2_triangles']=triangles.triangles_target.iloc[:train.shape[0]].values
# Out:
# CPU times: user 1.1 s, sys: 3.63 s, total: 4.73 s
# Wall time: 4.73 s

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles
# 0                1
# 1                2
# 2               40
# 3              193
# 4                5

# %%
# %%time
temp_df=pd.read_pickle('neigbours_vars_pat_leftover_2.pkl')
temp_df.columns=['deg2_feat1','deg2_feat2','deg2_feat3','deg2_feat4']
train=pd.concat((train,temp_df.iloc[:train.shape[0],:]),axis=1)
train.head()
# Out:
# CPU times: user 4.27 ms, sys: 192 µs, total: 4.46 ms
# Wall time: 4.07 ms

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5

# %%
# %%time
deg_2_neigh=pd.read_pickle('degree_2_neighbour_feats.pkl')
train=pd.concat((train,deg_2_neigh.iloc[:train.shape[0],:]),axis=1)
# Out:
# CPU times: user 5.04 ms, sys: 1.06 ms, total: 6.1 ms
# Wall time: 12.8 ms

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4  \
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5
#
#    degree_2_neighs_chat_sum_source  degree_2_neighs_chat_avg_source  \
# 0                               26                         0.702703
# 1                               37                         0.787234
# 2                               68                         1.478261
# 3                              101                         1.771930
# 4                               47                         0.691176
#
#    degree_2_neighs_chat_sum_target  degree_2_neighs_chat_avg_target  \
# 0                               11                         1.571429
# 1                               10                         0.909091
# 2                               44                         2.095238
# 3                              122                         1.794118
# 4                                7                         0.700000
#
#    mutual_neighs_avg_chat_sum  mutual_neighs_avg_chat_avg  \
# 0                           1                    1.000000
# 1                           0                         NaN
# 2                           7                    2.333333
# 3                          20                    2.857143
# 4                           0                    0.000000
#
#    union_neighs_avg_chat_sum  union_neighs_avg_chat_avg
# 0                         36                   0.837209
# 1                         47                   0.810345
# 2                        105                   1.640625
# 3                        203                   1.720339
# 4                         54                   0.701299

# %%
# %%time
dir_degrees=pd.read_pickle('directed_degrees.pkl')
train['directed_degree_source']= dir_degrees['directed_degree_source'].iloc[:train.shape[0]].values
train['directed_degree_target']= dir_degrees['directed_degree_target'].iloc[:train.shape[0]].values
train['directed_degree_source_in']= dir_degrees['directed_degree_source_in'].iloc[:train.shape[0]].values
train['directed_degree_target_in']= dir_degrees['directed_degree_target_in'].iloc[:train.shape[0]].values
train['directed_degree_source_out']= dir_degrees['directed_degree_source_out'].iloc[:train.shape[0]].values
train['directed_degree_target_out']= dir_degrees['directed_degree_target_out'].iloc[:train.shape[0]].values
# Out:
# CPU times: user 1.25 s, sys: 5.62 s, total: 6.87 s
# Wall time: 6.87 s

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4  \
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5
#
#    degree_2_neighs_chat_sum_source  degree_2_neighs_chat_avg_source  \
# 0                               26                         0.702703
# 1                               37                         0.787234
# 2                               68                         1.478261
# 3                              101                         1.771930
# 4                               47                         0.691176
#
#    degree_2_neighs_chat_sum_target  degree_2_neighs_chat_avg_target  \
# 0                               11                         1.571429
# 1                               10                         0.909091
# 2                               44                         2.095238
# 3                              122                         1.794118
# 4                                7                         0.700000
#
#    mutual_neighs_avg_chat_sum  mutual_neighs_avg_chat_avg  \
# 0                           1                    1.000000
# 1                           0                         NaN
# 2                           7                    2.333333
# 3                          20                    2.857143
# 4                           0                    0.000000
#
#    union_neighs_avg_chat_sum  union_neighs_avg_chat_avg  \
# 0                         36                   0.837209
# 1                         47                   0.810345
# 2                        105                   1.640625
# 3                        203                   1.720339
# 4                         54                   0.701299
#
#    directed_degree_source  directed_degree_target  directed_degree_source_in  \
# 0                0.000005            9.680221e-07                   0.000001
# 1                0.000007            1.452033e-06                   0.000002
# 2                0.000007            3.388077e-06                   0.000004
# 3                0.000009            1.197927e-05                   0.000004
# 4                0.000010            1.573036e-06                   0.000003
#
#    directed_degree_target_in  directed_degree_source_out  \
# 0               9.680221e-07                    0.000004
# 1               1.452033e-06                    0.000005
# 2               2.057047e-06                    0.000003
# 3               5.203118e-06                    0.000006
# 4               6.050137e-07                    0.000007
#
#    directed_degree_target_out
# 0                0.000000e+00
# 1                0.000000e+00
# 2                1.331030e-06
# 3                6.776154e-06
# 4                9.680221e-07

# %%
# %%time
neighbours=pd.read_csv('neigbours_vars_sahil_1.csv')
train['source_mutual_is_chat']=neighbours.iloc[:train.shape[0],1].values
train['target_mutual_is_chat']=neighbours.iloc[:train.shape[0],2].values
train['mutual_neighbours']=neighbours.iloc[:train.shape[0],0].values
# Out:
# CPU times: user 8.45 ms, sys: 414 µs, total: 8.87 ms
# Wall time: 21.2 ms

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4  \
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5
#
#    degree_2_neighs_chat_sum_source  degree_2_neighs_chat_avg_source  \
# 0                               26                         0.702703
# 1                               37                         0.787234
# 2                               68                         1.478261
# 3                              101                         1.771930
# 4                               47                         0.691176
#
#    degree_2_neighs_chat_sum_target  degree_2_neighs_chat_avg_target  \
# 0                               11                         1.571429
# 1                               10                         0.909091
# 2                               44                         2.095238
# 3                              122                         1.794118
# 4                                7                         0.700000
#
#    mutual_neighs_avg_chat_sum  mutual_neighs_avg_chat_avg  \
# 0                           1                    1.000000
# 1                           0                         NaN
# 2                           7                    2.333333
# 3                          20                    2.857143
# 4                           0                    0.000000
#
#    union_neighs_avg_chat_sum  union_neighs_avg_chat_avg  \
# 0                         36                   0.837209
# 1                         47                   0.810345
# 2                        105                   1.640625
# 3                        203                   1.720339
# 4                         54                   0.701299
#
#    directed_degree_source  directed_degree_target  directed_degree_source_in  \
# 0                0.000005            9.680221e-07                   0.000001
# 1                0.000007            1.452033e-06                   0.000002
# 2                0.000007            3.388077e-06                   0.000004
# 3                0.000009            1.197927e-05                   0.000004
# 4                0.000010            1.573036e-06                   0.000003
#
#    directed_degree_target_in  directed_degree_source_out  \
# 0               9.680221e-07                    0.000004
# 1               1.452033e-06                    0.000005
# 2               2.057047e-06                    0.000003
# 3               5.203118e-06                    0.000006
# 4               6.050137e-07                    0.000007
#
#    directed_degree_target_out  source_mutual_is_chat  target_mutual_is_chat  \
# 0                0.000000e+00                      0                      0
# 1                0.000000e+00                      0                      0
# 2                1.331030e-06                      0                      0
# 3                6.776154e-06                      0                      0
# 4                9.680221e-07                      0                      0
#
#    mutual_neighbours
# 0                  1
# 1                  0
# 2                  3
# 3                  7
# 4                  1

# %%
# %%time
neighbours2=pd.read_csv('neigbours_vars_sahil_2.csv')
train['source_is_chat_count']=neighbours2.iloc[:train.shape[0],0].values
train['target_is_chat_count']=neighbours2.iloc[:train.shape[0],1].values
# Out:
# CPU times: user 4.98 ms, sys: 1.25 ms, total: 6.23 ms
# Wall time: 13.6 ms

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4  \
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5
#
#    degree_2_neighs_chat_sum_source  degree_2_neighs_chat_avg_source  \
# 0                               26                         0.702703
# 1                               37                         0.787234
# 2                               68                         1.478261
# 3                              101                         1.771930
# 4                               47                         0.691176
#
#    degree_2_neighs_chat_sum_target  degree_2_neighs_chat_avg_target  \
# 0                               11                         1.571429
# 1                               10                         0.909091
# 2                               44                         2.095238
# 3                              122                         1.794118
# 4                                7                         0.700000
#
#    mutual_neighs_avg_chat_sum  mutual_neighs_avg_chat_avg  \
# 0                           1                    1.000000
# 1                           0                         NaN
# 2                           7                    2.333333
# 3                          20                    2.857143
# 4                           0                    0.000000
#
#    union_neighs_avg_chat_sum  union_neighs_avg_chat_avg  \
# 0                         36                   0.837209
# 1                         47                   0.810345
# 2                        105                   1.640625
# 3                        203                   1.720339
# 4                         54                   0.701299
#
#    directed_degree_source  directed_degree_target  directed_degree_source_in  \
# 0                0.000005            9.680221e-07                   0.000001
# 1                0.000007            1.452033e-06                   0.000002
# 2                0.000007            3.388077e-06                   0.000004
# 3                0.000009            1.197927e-05                   0.000004
# 4                0.000010            1.573036e-06                   0.000003
#
#    directed_degree_target_in  directed_degree_source_out  \
# 0               9.680221e-07                    0.000004
# 1               1.452033e-06                    0.000005
# 2               2.057047e-06                    0.000003
# 3               5.203118e-06                    0.000006
# 4               6.050137e-07                    0.000007
#
#    directed_degree_target_out  source_mutual_is_chat  target_mutual_is_chat  \
# 0                0.000000e+00                      0                      0
# 1                0.000000e+00                      0                      0
# 2                1.331030e-06                      0                      0
# 3                6.776154e-06                      0                      0
# 4                9.680221e-07                      0                      0
#
#    mutual_neighbours  source_is_chat_count  target_is_chat_count
# 0                  1                     0                     0
# 1                  0                     0                     0
# 2                  3                     1                     4
# 3                  7                     0                     0
# 4                  1                     2                     0

# %%
# %%time
def change_dtype(a,dt):
    return a.astype(dt)
for col in train.columns[train.columns.str.contains('f[0-9]')].tolist():
    train[col]=change_dtype(train[col],'int16')
# Out:
# CPU times: user 9.81 ms, sys: 6.34 ms, total: 16.1 ms
# Wall time: 12.4 ms

# %%
gc.collect()
# Out:
# 263

# %%
# train.shape

# %%
# %%time
extra_feats=pd.read_csv('jc_rsa_pa_aai.csv')
extra_feats.rsa = extra_feats.rsa.shift(1).fillna(0)
train['jc']= extra_feats.jc.iloc[:train.shape[0]].values
train['rsa']= extra_feats.rsa.iloc[:train.shape[0]].values
train['pa']= extra_feats.pa.iloc[:train.shape[0]].values
train['adamic_adar']= extra_feats.aa.iloc[:train.shape[0]].values
# Out:
# CPU times: user 6.58 ms, sys: 0 ns, total: 6.58 ms
# Wall time: 5.86 ms

# %%
gc.collect()
# Out:
# 23

# %%
leak_feature=pd.read_pickle('leak_feature.pkl')
train['leak_feature']=leak_feature.leak_feature.iloc[:train.shape[0]].values
#train['is_duplicated']=leak_feature.b.iloc[:train.shape[0]].values

# %%
gc.collect()
# Out:
# 35

# %%
train.shape
# Out:
# (70661802, 63)

# %%
train.head()
# Out:
#    node1_id  node2_id  degree_source  degree_target  f1_source_target  \
# 0        31         8       0.000005   9.680221e-07                22
# 1        41        12       0.000006   1.452033e-06                 0
# 2        28        17       0.000006   2.662061e-06                 9
# 3        47        43       0.000007   8.591195e-06                11
# 4        58         5       0.000008   1.331030e-06                31
#
#    f2_source_target  f3_source_target  f4_source_target  f5_source_target  \
# 0                 0                 0                24                 0
# 1                 0                 0                 0                 0
# 2                 2                 0                14                 7
# 3                11                10                11                10
# 4                31                31                31                31
#
#    f6_source_target  f7_source_target  f8_source_target  f9_source_target  \
# 0                 0                24                 0                 0
# 1                 0                 0                 0                 0
# 2                 1                14                 7                 1
# 3                 9                10                 9                 8
# 4                31                31                31                31
#
#    f10_source_target  f11_source_target  f12_source_target  f13_source_target  \
# 0                 26                  0                  0                 15
# 1                  0                  0                  0                  7
# 2                 14                  7                  1                 15
# 3                  7                  6                  6                  7
# 4                 31                 31                 30                  7
#
#    f1_target  f2_target  f3_target  f4_target  f5_target  f6_target  \
# 0         22         15          5         15         11          5
# 1          9          8          6         16         13          6
# 2          1          1          0          1          1          0
# 3          0          0          0          1          1          1
# 4          3          1          0          7          1          0
#
#    f7_target  f8_target  f9_target  f10_target  f11_target  f12_target  \
# 0         19         12          5          16          10           4
# 1         20         16          7          25          21           6
# 2          1          1          0           0           0           0
# 3          1          1          1           1           1           1
# 4          9          1          0          16           1           0
#
#    f13_target  is_chat  node1_cluster  node2_cluster  node1_triangles  \
# 0          10        0       0.025604       0.035706               18
# 1          15        0       0.055847       0.030304               63
# 2           8        0       0.029602       0.173218               32
# 3          15        0       0.037506       0.082275               62
# 4           7        0       0.019180       0.090881               45
#
#    node2_triangles  deg2_feat1  deg2_feat2  deg2_feat3  deg2_feat4  \
# 0                1           0         NaN           0         NaN
# 1                2           0         NaN           0         NaN
# 2               40           0         NaN          23         4.6
# 3              193           0         NaN           0         NaN
# 4                5           0         NaN           5         2.5
#
#    degree_2_neighs_chat_sum_source  degree_2_neighs_chat_avg_source  \
# 0                               26                         0.702703
# 1                               37                         0.787234
# 2                               68                         1.478261
# 3                              101                         1.771930
# 4                               47                         0.691176
#
#    degree_2_neighs_chat_sum_target  degree_2_neighs_chat_avg_target  \
# 0                               11                         1.571429
# 1                               10                         0.909091
# 2                               44                         2.095238
# 3                              122                         1.794118
# 4                                7                         0.700000
#
#    mutual_neighs_avg_chat_sum  mutual_neighs_avg_chat_avg  \
# 0                           1                    1.000000
# 1                           0                         NaN
# 2                           7                    2.333333
# 3                          20                    2.857143
# 4                           0                    0.000000
#
#    union_neighs_avg_chat_sum  union_neighs_avg_chat_avg  \
# 0                         36                   0.837209
# 1                         47                   0.810345
# 2                        105                   1.640625
# 3                        203                   1.720339
# 4                         54                   0.701299
#
#    directed_degree_source  directed_degree_target  directed_degree_source_in  \
# 0                0.000005            9.680221e-07                   0.000001
# 1                0.000007            1.452033e-06                   0.000002
# 2                0.000007            3.388077e-06                   0.000004
# 3                0.000009            1.197927e-05                   0.000004
# 4                0.000010            1.573036e-06                   0.000003
#
#    directed_degree_target_in  directed_degree_source_out  \
# 0               9.680221e-07                    0.000004
# 1               1.452033e-06                    0.000005
# 2               2.057047e-06                    0.000003
# 3               5.203118e-06                    0.000006
# 4               6.050137e-07                    0.000007
#
#    directed_degree_target_out  source_mutual_is_chat  target_mutual_is_chat  \
# 0                0.000000e+00                      0                      0
# 1                0.000000e+00                      0                      0
# 2                1.331030e-06                      0                      0
# 3                6.776154e-06                      0                      0
# 4                9.680221e-07                      0                      0
#
#    mutual_neighbours  source_is_chat_count  target_is_chat_count        jc  \
# 0                  1                     0                     0  0.022222
# 1                  0                     0                     0  0.000000
# 2                  3                     1                     4  0.045455
# 3                  7                     0                     0  0.058333
# 4                  1                     2                     0  0.012658
#
#         rsa    pa  adamic_adar  leak_feature  degree_ratio  degree_delta  \
# 0  0.000000   320     0.225692            -1      0.000005      0.000004
# 1  0.011905   600     0.000000            -1      0.000006      0.000005
# 2  0.000000  1078     0.840082            -1      0.000006      0.000003
# 3  0.086736  4118     1.772571            -1      0.000007     -0.000002
# 4  0.137000   759     0.276938            -1      0.000008      0.000007
#
#    directed_degree_ratio  directed_degree_delta  directed_degree_ratio_in  \
# 0               0.000005               0.000004                  0.000001
# 1               0.000007               0.000005                  0.000002
# 2               0.000007               0.000004                  0.000004
# 3               0.000009              -0.000003                  0.000004
# 4               0.000010               0.000008                  0.000003
#
#    directed_degree_delta_in  directed_degree_ratio_out  \
# 0              2.420054e-07                   0.000004
# 1              4.840111e-07                   0.000005
# 2              1.815042e-06                   0.000003
# 3             -1.694038e-06                   0.000006
# 4              2.178050e-06                   0.000007
#
#    directed_degree_delta_out  node_sum  node_ratio  is_chat_diff  \
# 0                   0.000004        39    3.875000             0
# 1                   0.000005        53    3.416016             0
# 2                   0.000002        45    1.647461            -3
# 3                  -0.000001        90    1.092773             0
# 4                   0.000006        63   11.601562             2
#
#    is_chat_ratio  mutual_chat_diff  mutual_chat_ratio  delta_triangle  \
# 0            0.0                 0                0.0              17
# 1            0.0                 0                0.0              61
# 2            0.2                 0                0.0              -8
# 3            0.0                 0                0.0            -131
# 4            2.0                 0                0.0              40
#
#    ratio_triangle  triangle_degree_delta_source  triangle_degree_delta_target  \
# 0        9.000000                            22                           -10
# 1       21.000000                           -13                           -51
# 2        0.780488                            17                           -10
# 3        0.319588                            -4                             9
# 4        7.500000                            24                           -34
#
#    clust_prod  clust_diff  source_net_act  target_net_act  net_act_diff  \
# 0    0.000914   -0.010101              96             139           -43
# 1    0.001693    0.025543               0             153          -153
# 2    0.005127   -0.143555              77               6            71
# 3    0.003086   -0.044769             108               9            99
# 4    0.001743   -0.071716             371              39           332
#
#    f14_source  f15_source  f16_source  f14_target  f15_target  f16_target  \
# 0          96           0           0          72          33          14
# 1           0           0           0          70          50          19
# 2          51          21           3           3           2           0
# 3          39          25          23           3           3           3
# 4         124          93          92          35           3           0
#
#    fdiff_1  fdiff_2  fdiff_3  fdiff_4  fdiff_5  fdiff_6  fdiff_7  fdiff_8  \
# 0        0      -15       -5        9      -11       -5        5      -12
# 1       -9       -8       -6      -16      -13       -6      -20      -16
# 2        8        1        0       13        6        1       13        6
# 3       11       11       10       10        9        8        9        8
# 4       28       30       31       24       30       31       22       30
#
#    fdiff_9  fdiff_10  fdiff_11  fdiff_12  fdiff_13  fdiff_14  fdiff_15  \
# 0       -5        10       -10        -4         5       -24        33
# 1       -7       -25       -21        -6        -8        70        50
# 2        1        14         7         1         7       -48       -19
# 3        7         6         5         5        -8       -36       -22
# 4       31        15        30        30         0       -89       -90
#
#    fdiff_16    fmult_1  fmult_2  fmult_3  fmult_4  fmult_5  fmult_6  fmult_7  \
# 0        14   0.956522      0.0      0.0    1.500      0.0      0.0      1.2
# 1        19   0.000000      0.0      0.0    0.000      0.0      0.0      0.0
# 2        -3   4.500000      1.0      0.0    7.000      3.5      1.0      7.0
# 3       -20  11.000000     11.0     10.0    5.500      5.0      4.5      5.0
# 4       -92   7.750000     15.5     31.0    3.875     15.5     31.0      3.1
#
#    fmult_8  fmult_9   fmult_10  fmult_11  fmult_12  fmult_13   fmult_14  \
# 0      0.0      0.0   1.529412       0.0       0.0  1.363636   1.315068
# 1      0.0      0.0   0.000000       0.0       0.0  0.437500   0.000000
# 2      3.5      1.0  14.000000       7.0       1.0  1.666667  12.750000
# 3      4.5      4.0   3.500000       3.0       3.0  0.437500   9.750000
# 4     15.5     31.0   1.823529      15.5      30.0  0.875000   3.444444
#
#    fmult_15  fmult_16  norm_user_diff  norm_user_diff_1  norm_user_diff_2  \
# 0      0.00      0.00         68.0000         14.352700         24.289916
# 1      0.00      0.00        183.5000         36.905284         30.495901
# 2      7.00      3.00         92.1875         24.454039         11.045361
# 3      6.25      5.75        113.6250         18.384776         17.058722
# 4     23.25     92.00        114.4375         45.486262         60.000000
#
#    norm_user_diff_3
# 0          9.539392
# 1         12.529964
# 2          1.732051
# 3         15.427249
# 4         61.506097

# %%
def neg_sample_estimator(train_df,est,seed,frac=0.05):
    temp_train=train_df[train_df.is_chat==0].sample(frac=frac,random_state=seed)
    df=pd.concat((temp_train,train_df[train_df.is_chat==1]),axis=0)
    df=df.sample(frac=1,random_state=seed)
    y=df.is_chat
    df.drop('is_chat',inplace=True,axis=1)
    gc.collect()
    est.get_repeated_out_of_folds(df.values,y.values)
    return est

# %%
def neg_sample_data(train_df,seed,frac=0.05):
    temp_train=train_df[train_df.is_chat==0].sample(frac=frac,random_state=seed)
    df=pd.concat((temp_train,train_df[train_df.is_chat==1]),axis=0)
    df=df.sample(frac=1,random_state=seed)
    y=df.is_chat
    df.drop('is_chat',inplace=True,axis=1)
    gc.collect()
    return df,y

# %%
# %%time
train=create_feats(train)
# Out:
# CPU times: user 592 ms, sys: 0 ns, total: 592 ms
# Wall time: 702 ms
# /home/weightsandbias/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in sqrt

# %%
train.shape
# Out:
# (70661802, 128)

# %% [markdown]
# #### Model building

# %%
params={'num_leaves': 256, 'n_jobs': -1, 'colsample_bytree': 0.8, 
        'learning_rate': 0.1, 'min_child_weight': 200.0, 'n_estimators': 1000,
        'subsample': 1.0, 'objective': 'binary', 'bagging_freq': 5, 'boosting_type': 'gbdt'}

mod=Estimator(model=LGBMClassifier(**params),n_jobs=-1,n_splits=5,random_state=100,shuffle=True,early_stopping_rounds=100)

# %%
del clust,extra_feats,leak_feature,dir_degrees,triangles,neighbours,neighbours2,deg_2_neigh,temp_df

# %%
gc.collect()
# Out:
# 802

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=100,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=200,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_200.pkl')
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938757	valid_0's binary_logloss: 0.302289	valid_1's auc: 0.940718	valid_1's binary_logloss: 0.297629
# [200]	valid_0's auc: 0.939858	valid_0's binary_logloss: 0.29932	valid_1's auc: 0.943662	valid_1's binary_logloss: 0.290086
# [300]	valid_0's auc: 0.940091	valid_0's binary_logloss: 0.298691	valid_1's auc: 0.945636	valid_1's binary_logloss: 0.285223
# [400]	valid_0's auc: 0.940161	valid_0's binary_logloss: 0.298487	valid_1's auc: 0.947364	valid_1's binary_logloss: 0.280999
# [500]	valid_0's auc: 0.940193	valid_0's binary_logloss: 0.298378	valid_1's auc: 0.949003	valid_1's binary_logloss: 0.276993
# Early stopping, best iteration is:
# [498]	valid_0's auc: 0.940194	valid_0's binary_logloss: 0.298376	valid_1's auc: 0.948967	valid_1's binary_logloss: 0.277079
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938349	valid_0's binary_logloss: 0.303061	valid_1's auc: 0.940791	valid_1's binary_logloss: 0.297528
# [200]	valid_0's auc: 0.939532	valid_0's binary_logloss: 0.299895	valid_1's auc: 0.943766	valid_1's binary_logloss: 0.289903
# [300]	valid_0's auc: 0.939728	valid_0's binary_logloss: 0.299358	valid_1's auc: 0.945706	valid_1's binary_logloss: 0.28513
# [400]	valid_0's auc: 0.939821	valid_0's binary_logloss: 0.299117	valid_1's auc: 0.947456	valid_1's binary_logloss: 0.280818
# [500]	valid_0's auc: 0.939815	valid_0's binary_logloss: 0.299104	valid_1's auc: 0.949054	valid_1's binary_logloss: 0.276897
# [600]	valid_0's auc: 0.939814	valid_0's binary_logloss: 0.299099	valid_1's auc: 0.950598	valid_1's binary_logloss: 0.273098
# Early stopping, best iteration is:
# [577]	valid_0's auc: 0.93983	valid_0's binary_logloss: 0.299065	valid_1's auc: 0.950258	valid_1's binary_logloss: 0.273932
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938753	valid_0's binary_logloss: 0.302121	valid_1's auc: 0.940664	valid_1's binary_logloss: 0.297812
# [200]	valid_0's auc: 0.939919	valid_0's binary_logloss: 0.299021	valid_1's auc: 0.943654	valid_1's binary_logloss: 0.290207
# [300]	valid_0's auc: 0.940127	valid_0's binary_logloss: 0.298445	valid_1's auc: 0.945605	valid_1's binary_logloss: 0.285399
# [400]	valid_0's auc: 0.940191	valid_0's binary_logloss: 0.298264	valid_1's auc: 0.947325	valid_1's binary_logloss: 0.28117
# [500]	valid_0's auc: 0.94021	valid_0's binary_logloss: 0.298201	valid_1's auc: 0.948955	valid_1's binary_logloss: 0.277174
# [600]	valid_0's auc: 0.940217	valid_0's binary_logloss: 0.298168	valid_1's auc: 0.950521	valid_1's binary_logloss: 0.27333
# Early stopping, best iteration is:
# [536]	valid_0's auc: 0.940227	valid_0's binary_logloss: 0.298154	valid_1's auc: 0.949553	valid_1's binary_logloss: 0.275729
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.939168	valid_0's binary_logloss: 0.301091	valid_1's auc: 0.940612	valid_1's binary_logloss: 0.29796
# [200]	valid_0's auc: 0.940325	valid_0's binary_logloss: 0.297944	valid_1's auc: 0.943588	valid_1's binary_logloss: 0.290397
# [300]	valid_0's auc: 0.940545	valid_0's binary_logloss: 0.297322	valid_1's auc: 0.945556	valid_1's binary_logloss: 0.285544
# [400]	valid_0's auc: 0.940636	valid_0's binary_logloss: 0.297058	valid_1's auc: 0.947299	valid_1's binary_logloss: 0.281291
# [500]	valid_0's auc: 0.940655	valid_0's binary_logloss: 0.296988	valid_1's auc: 0.948918	valid_1's binary_logloss: 0.277327
# Early stopping, best iteration is:
# [498]	valid_0's auc: 0.940658	valid_0's binary_logloss: 0.296982	valid_1's auc: 0.948886	valid_1's binary_logloss: 0.277408
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938793	valid_0's binary_logloss: 0.302195	valid_1's auc: 0.940731	valid_1's binary_logloss: 0.297588
# [200]	valid_0's auc: 0.939907	valid_0's binary_logloss: 0.299182	valid_1's auc: 0.943659	valid_1's binary_logloss: 0.290124
# [300]	valid_0's auc: 0.940125	valid_0's binary_logloss: 0.298571	valid_1's auc: 0.945626	valid_1's binary_logloss: 0.285262
# [400]	valid_0's auc: 0.940213	valid_0's binary_logloss: 0.298325	valid_1's auc: 0.9474	valid_1's binary_logloss: 0.28095
# [500]	valid_0's auc: 0.940221	valid_0's binary_logloss: 0.298282	valid_1's auc: 0.949001	valid_1's binary_logloss: 0.277023
# Early stopping, best iteration is:
# [472]	valid_0's auc: 0.940233	valid_0's binary_logloss: 0.298258	valid_1's auc: 0.948571	valid_1's binary_logloss: 0.27807
# CPU times: user 20h 15min 40s, sys: 9h 12min 12s, total: 1d 5h 27min 53s
# Wall time: 1h 24min

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score
# Out:
# mod2 [0.9401937317733958, 0.9398295974413856, 0.9402266619931113, 0.9406578657752643, 0.9402328778769024] 0.940228146972012

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=300,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_300.pkl')
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938295	valid_0's binary_logloss: 0.303274	valid_1's auc: 0.940799	valid_1's binary_logloss: 0.297475
# [200]	valid_0's auc: 0.939522	valid_0's binary_logloss: 0.300028	valid_1's auc: 0.943794	valid_1's binary_logloss: 0.289833
# [300]	valid_0's auc: 0.939718	valid_0's binary_logloss: 0.299495	valid_1's auc: 0.945745	valid_1's binary_logloss: 0.285054
# [400]	valid_0's auc: 0.939771	valid_0's binary_logloss: 0.299344	valid_1's auc: 0.947441	valid_1's binary_logloss: 0.280852
# [500]	valid_0's auc: 0.939808	valid_0's binary_logloss: 0.299236	valid_1's auc: 0.949055	valid_1's binary_logloss: 0.276886
# [600]	valid_0's auc: 0.939807	valid_0's binary_logloss: 0.299227	valid_1's auc: 0.950573	valid_1's binary_logloss: 0.273117
# Early stopping, best iteration is:
# [547]	valid_0's auc: 0.939827	valid_0's binary_logloss: 0.299183	valid_1's auc: 0.949808	valid_1's binary_logloss: 0.275024
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.939009	valid_0's binary_logloss: 0.301648	valid_1's auc: 0.940644	valid_1's binary_logloss: 0.29786
# [200]	valid_0's auc: 0.940131	valid_0's binary_logloss: 0.298603	valid_1's auc: 0.943588	valid_1's binary_logloss: 0.290358
# [300]	valid_0's auc: 0.940364	valid_0's binary_logloss: 0.297979	valid_1's auc: 0.945541	valid_1's binary_logloss: 0.285523
# [400]	valid_0's auc: 0.94043	valid_0's binary_logloss: 0.297779	valid_1's auc: 0.947299	valid_1's binary_logloss: 0.281265
# [500]	valid_0's auc: 0.940437	valid_0's binary_logloss: 0.297738	valid_1's auc: 0.9489	valid_1's binary_logloss: 0.277328
# Early stopping, best iteration is:
# [484]	valid_0's auc: 0.940448	valid_0's binary_logloss: 0.297713	valid_1's auc: 0.948652	valid_1's binary_logloss: 0.277928
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.939127	valid_0's binary_logloss: 0.30126	valid_1's auc: 0.940632	valid_1's binary_logloss: 0.297869
# [200]	valid_0's auc: 0.940247	valid_0's binary_logloss: 0.29823	valid_1's auc: 0.943567	valid_1's binary_logloss: 0.290392
# [300]	valid_0's auc: 0.940457	valid_0's binary_logloss: 0.297672	valid_1's auc: 0.945501	valid_1's binary_logloss: 0.285641
# [400]	valid_0's auc: 0.940534	valid_0's binary_logloss: 0.297441	valid_1's auc: 0.947257	valid_1's binary_logloss: 0.281345
# [500]	valid_0's auc: 0.940567	valid_0's binary_logloss: 0.297337	valid_1's auc: 0.948924	valid_1's binary_logloss: 0.27731
# Early stopping, best iteration is:
# [459]	valid_0's auc: 0.94058	valid_0's binary_logloss: 0.297319	valid_1's auc: 0.94826	valid_1's binary_logloss: 0.27891
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938721	valid_0's binary_logloss: 0.302175	valid_1's auc: 0.940699	valid_1's binary_logloss: 0.297761
# [200]	valid_0's auc: 0.939833	valid_0's binary_logloss: 0.299179	valid_1's auc: 0.943637	valid_1's binary_logloss: 0.29026
# [300]	valid_0's auc: 0.94007	valid_0's binary_logloss: 0.298549	valid_1's auc: 0.945605	valid_1's binary_logloss: 0.285422
# [400]	valid_0's auc: 0.940186	valid_0's binary_logloss: 0.298227	valid_1's auc: 0.947382	valid_1's binary_logloss: 0.281085
# [500]	valid_0's auc: 0.940203	valid_0's binary_logloss: 0.298159	valid_1's auc: 0.949004	valid_1's binary_logloss: 0.277116
# [600]	valid_0's auc: 0.940193	valid_0's binary_logloss: 0.298171	valid_1's auc: 0.950564	valid_1's binary_logloss: 0.273275
# Early stopping, best iteration is:
# [547]	valid_0's auc: 0.940209	valid_0's binary_logloss: 0.298141	valid_1's auc: 0.949755	valid_1's binary_logloss: 0.275262
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938687	valid_0's binary_logloss: 0.302446	valid_1's auc: 0.940705	valid_1's binary_logloss: 0.297714
# [200]	valid_0's auc: 0.939865	valid_0's binary_logloss: 0.299273	valid_1's auc: 0.943722	valid_1's binary_logloss: 0.290023
# [300]	valid_0's auc: 0.94006	valid_0's binary_logloss: 0.298754	valid_1's auc: 0.945667	valid_1's binary_logloss: 0.285214
# [400]	valid_0's auc: 0.940129	valid_0's binary_logloss: 0.298565	valid_1's auc: 0.947409	valid_1's binary_logloss: 0.280955
# [500]	valid_0's auc: 0.940152	valid_0's binary_logloss: 0.29849	valid_1's auc: 0.949049	valid_1's binary_logloss: 0.276975
# [600]	valid_0's auc: 0.940157	valid_0's binary_logloss: 0.298452	valid_1's auc: 0.950583	valid_1's binary_logloss: 0.273168
# Early stopping, best iteration is:
# [555]	valid_0's auc: 0.94017	valid_0's binary_logloss: 0.298425	valid_1's auc: 0.94993	valid_1's binary_logloss: 0.274795
# CPU times: user 20h 30min 31s, sys: 9h 23min 48s, total: 1d 5h 54min 20s
# Wall time: 1h 25min 36s

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score
# Out:
# mod2 [0.9398269590461181, 0.9404481181971962, 0.9405796764435808, 0.9402091424270741, 0.9401698169609554] 0.9402467426149848

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=400,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_400.pkl')
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938727	valid_0's binary_logloss: 0.302271	valid_1's auc: 0.940692	valid_1's binary_logloss: 0.297796
# [200]	valid_0's auc: 0.939872	valid_0's binary_logloss: 0.299215	valid_1's auc: 0.94367	valid_1's binary_logloss: 0.290231
# [300]	valid_0's auc: 0.940111	valid_0's binary_logloss: 0.298567	valid_1's auc: 0.945617	valid_1's binary_logloss: 0.285397
# [400]	valid_0's auc: 0.940196	valid_0's binary_logloss: 0.298317	valid_1's auc: 0.947371	valid_1's binary_logloss: 0.281145
# [500]	valid_0's auc: 0.940231	valid_0's binary_logloss: 0.298209	valid_1's auc: 0.949005	valid_1's binary_logloss: 0.277119
# Early stopping, best iteration is:
# [492]	valid_0's auc: 0.940233	valid_0's binary_logloss: 0.298205	valid_1's auc: 0.948883	valid_1's binary_logloss: 0.277418
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.939158	valid_0's binary_logloss: 0.301403	valid_1's auc: 0.940594	valid_1's binary_logloss: 0.297989
# [200]	valid_0's auc: 0.94028	valid_0's binary_logloss: 0.298364	valid_1's auc: 0.943574	valid_1's binary_logloss: 0.290399
# [300]	valid_0's auc: 0.940511	valid_0's binary_logloss: 0.297749	valid_1's auc: 0.945551	valid_1's binary_logloss: 0.285542
# [400]	valid_0's auc: 0.940558	valid_0's binary_logloss: 0.297607	valid_1's auc: 0.947287	valid_1's binary_logloss: 0.281297
# [500]	valid_0's auc: 0.940571	valid_0's binary_logloss: 0.29755	valid_1's auc: 0.948896	valid_1's binary_logloss: 0.277372
# Early stopping, best iteration is:
# [473]	valid_0's auc: 0.940579	valid_0's binary_logloss: 0.29753	valid_1's auc: 0.948474	valid_1's binary_logloss: 0.278393
# Training until validation scores don't improve for 100 rounds.
# [300]	valid_0's auc: 0.939774	valid_0's binary_logloss: 0.299398	valid_1's auc: 0.945779	valid_1's binary_logloss: 0.285023
# [400]	valid_0's auc: 0.939853	valid_0's binary_logloss: 0.299176	valid_1's auc: 0.94753	valid_1's binary_logloss: 0.28068
# [500]	valid_0's auc: 0.939879	valid_0's binary_logloss: 0.299093	valid_1's auc: 0.949183	valid_1's binary_logloss: 0.276666
# [600]	valid_0's auc: 0.939872	valid_0's binary_logloss: 0.299095	valid_1's auc: 0.950748	valid_1's binary_logloss: 0.272799
# Early stopping, best iteration is:
# [534]	valid_0's auc: 0.939888	valid_0's binary_logloss: 0.299067	valid_1's auc: 0.949739	valid_1's binary_logloss: 0.275289
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938655	valid_0's binary_logloss: 0.30234	valid_1's auc: 0.940715	valid_1's binary_logloss: 0.297751
# [200]	valid_0's auc: 0.939856	valid_0's binary_logloss: 0.299135	valid_1's auc: 0.943694	valid_1's binary_logloss: 0.290134
# [300]	valid_0's auc: 0.940059	valid_0's binary_logloss: 0.298594	valid_1's auc: 0.945647	valid_1's binary_logloss: 0.285334
# [400]	valid_0's auc: 0.940137	valid_0's binary_logloss: 0.298365	valid_1's auc: 0.947394	valid_1's binary_logloss: 0.281065
# [500]	valid_0's auc: 0.940148	valid_0's binary_logloss: 0.298308	valid_1's auc: 0.949007	valid_1's binary_logloss: 0.277087
# Early stopping, best iteration is:
# [478]	valid_0's auc: 0.940156	valid_0's binary_logloss: 0.298292	valid_1's auc: 0.948676	valid_1's binary_logloss: 0.277905
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938833	valid_0's binary_logloss: 0.301982	valid_1's auc: 0.940688	valid_1's binary_logloss: 0.297778
# [200]	valid_0's auc: 0.939976	valid_0's binary_logloss: 0.298901	valid_1's auc: 0.943634	valid_1's binary_logloss: 0.290296
# [300]	valid_0's auc: 0.940222	valid_0's binary_logloss: 0.29826	valid_1's auc: 0.945603	valid_1's binary_logloss: 0.285469
# [400]	valid_0's auc: 0.940313	valid_0's binary_logloss: 0.297991	valid_1's auc: 0.947367	valid_1's binary_logloss: 0.28113
# [500]	valid_0's auc: 0.940344	valid_0's binary_logloss: 0.29787	valid_1's auc: 0.948971	valid_1's binary_logloss: 0.277162
# Early stopping, best iteration is:
# [493]	valid_0's auc: 0.940345	valid_0's binary_logloss: 0.297868	valid_1's auc: 0.948864	valid_1's binary_logloss: 0.277425
# CPU times: user 19h 45min 16s, sys: 9h 7min 53s, total: 1d 4h 53min 9s
# Wall time: 1h 23min 10s

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score
# Out:
# mod2 [0.9402334102242799, 0.94057945273079, 0.9398875814444789, 0.9401557522279543, 0.9403453260778156] 0.9402403045410637

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=500,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_500.pkl')
# Out:
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938481	valid_0's binary_logloss: 0.30291	valid_1's auc: 0.94068	valid_1's binary_logloss: 0.29784
# [200]	valid_0's auc: 0.939639	valid_0's binary_logloss: 0.29981	valid_1's auc: 0.943652	valid_1's binary_logloss: 0.290225
# [300]	valid_0's auc: 0.939858	valid_0's binary_logloss: 0.299237	valid_1's auc: 0.945603	valid_1's binary_logloss: 0.285394
# [400]	valid_0's auc: 0.939931	valid_0's binary_logloss: 0.299015	valid_1's auc: 0.947342	valid_1's binary_logloss: 0.28113
# [500]	valid_0's auc: 0.939959	valid_0's binary_logloss: 0.298926	valid_1's auc: 0.948977	valid_1's binary_logloss: 0.27712
# [600]	valid_0's auc: 0.939954	valid_0's binary_logloss: 0.298922	valid_1's auc: 0.950523	valid_1's binary_logloss: 0.273352
# Early stopping, best iteration is:
# [547]	valid_0's auc: 0.939968	valid_0's binary_logloss: 0.298893	valid_1's auc: 0.949717	valid_1's binary_logloss: 0.275305
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.939177	valid_0's binary_logloss: 0.301209	valid_1's auc: 0.940529	valid_1's binary_logloss: 0.298203
# [200]	valid_0's auc: 0.940325	valid_0's binary_logloss: 0.298119	valid_1's auc: 0.943474	valid_1's binary_logloss: 0.290716
# [300]	valid_0's auc: 0.940565	valid_0's binary_logloss: 0.297476	valid_1's auc: 0.945448	valid_1's binary_logloss: 0.285831
# [400]	valid_0's auc: 0.940636	valid_0's binary_logloss: 0.297256	valid_1's auc: 0.947199	valid_1's binary_logloss: 0.281567
# [500]	valid_0's auc: 0.940651	valid_0's binary_logloss: 0.297198	valid_1's auc: 0.948824	valid_1's binary_logloss: 0.277626
# Early stopping, best iteration is:
# [484]	valid_0's auc: 0.94066	valid_0's binary_logloss: 0.297176	valid_1's auc: 0.948577	valid_1's binary_logloss: 0.278224
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938676	valid_0's binary_logloss: 0.302409	valid_1's auc: 0.940631	valid_1's binary_logloss: 0.297984
# [200]	valid_0's auc: 0.939866	valid_0's binary_logloss: 0.299244	valid_1's auc: 0.943578	valid_1's binary_logloss: 0.290494
# [300]	valid_0's auc: 0.940091	valid_0's binary_logloss: 0.298627	valid_1's auc: 0.945507	valid_1's binary_logloss: 0.285697
# [400]	valid_0's auc: 0.940194	valid_0's binary_logloss: 0.298336	valid_1's auc: 0.947265	valid_1's binary_logloss: 0.28136
# [500]	valid_0's auc: 0.940228	valid_0's binary_logloss: 0.298227	valid_1's auc: 0.948869	valid_1's binary_logloss: 0.277436
# [600]	valid_0's auc: 0.940195	valid_0's binary_logloss: 0.298293	valid_1's auc: 0.950391	valid_1's binary_logloss: 0.273695
# Early stopping, best iteration is:
# [502]	valid_0's auc: 0.940228	valid_0's binary_logloss: 0.298226	valid_1's auc: 0.948898	valid_1's binary_logloss: 0.277366
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938771	valid_0's binary_logloss: 0.302216	valid_1's auc: 0.940655	valid_1's binary_logloss: 0.297922
# [200]	valid_0's auc: 0.939855	valid_0's binary_logloss: 0.299262	valid_1's auc: 0.943591	valid_1's binary_logloss: 0.290405
# [300]	valid_0's auc: 0.940057	valid_0's binary_logloss: 0.298716	valid_1's auc: 0.945551	valid_1's binary_logloss: 0.285586
# [400]	valid_0's auc: 0.940124	valid_0's binary_logloss: 0.298521	valid_1's auc: 0.947291	valid_1's binary_logloss: 0.281314
# [500]	valid_0's auc: 0.940136	valid_0's binary_logloss: 0.298476	valid_1's auc: 0.948913	valid_1's binary_logloss: 0.27735
# [600]	valid_0's auc: 0.940135	valid_0's binary_logloss: 0.298462	valid_1's auc: 0.950499	valid_1's binary_logloss: 0.27347
# Early stopping, best iteration is:
# [541]	valid_0's auc: 0.94016	valid_0's binary_logloss: 0.298408	valid_1's auc: 0.9496	valid_1's binary_logloss: 0.275682
# Training until validation scores don't improve for 100 rounds.
# [100]	valid_0's auc: 0.938438	valid_0's binary_logloss: 0.303063	valid_1's auc: 0.940678	valid_1's binary_logloss: 0.297864
# [200]	valid_0's auc: 0.939598	valid_0's binary_logloss: 0.299961	valid_1's auc: 0.943656	valid_1's binary_logloss: 0.290217
# [300]	valid_0's auc: 0.93975	valid_0's binary_logloss: 0.299548	valid_1's auc: 0.945554	valid_1's binary_logloss: 0.285576
# [400]	valid_0's auc: 0.939833	valid_0's binary_logloss: 0.299332	valid_1's auc: 0.947291	valid_1's binary_logloss: 0.281317
# [500]	valid_0's auc: 0.939862	valid_0's binary_logloss: 0.299242	valid_1's auc: 0.948885	valid_1's binary_logloss: 0.277397
# [600]	valid_0's auc: 0.939855	valid_0's binary_logloss: 0.299249	valid_1's auc: 0.950422	valid_1's binary_logloss: 0.273616
# Early stopping, best iteration is:
# [562]	valid_0's auc: 0.93988	valid_0's binary_logloss: 0.299197	valid_1's auc: 0.949865	valid_1's binary_logloss: 0.274988
# CPU times: user 20h 39min 10s, sys: 9h 24min 11s, total: 1d 6h 3min 22s
# Wall time: 1h 26min 1s

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score
# Out:
# mod2 [0.939968206676806, 0.9406600446099929, 0.9402283883290528, 0.9401602258962751, 0.9398803930793797] 0.9401794517183013

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=600,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_600.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=700,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_700.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=800,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_800.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=900,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_900.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score

# %%
# %%time
mod2=neg_sample_estimator(est=mod,frac=0.05,seed=1000,train_df=train)
joblib.dump(mod2,'lgb_128_feats_with_leak_and_mutual_friends_with_is_chat_target_depth_2_feats_rsa_2_more_deg2_seed_1000.pkl')

# %%
print 'mod2',mod2.cv_scores, mod2.avg_cv_score
